# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = open('pred.txt').read()

# %%
plt.plot(map(float, data.split(',')))

# %%
data1 = open('pred1.txt').read()

# %%
plt.plot()

# %%
d1 = map(float, data.split(','))
d2 = map(float, data1.split(','))

# %%
plt.figure(figsize=(20,10))
plt.plot(d1[:24*30])
plt.plot(d2[:24*30])
